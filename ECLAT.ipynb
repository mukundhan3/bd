# %%
kot = 0
FreqItems = dict()
support = dict()
def eclat(prefix, items, dict_id):
    while items:
        i,itids = items.pop()
        isupp = len(itids)
        if isupp >= minsup:

            FreqItems[frozenset(prefix + [i])] = isupp
            suffix = []
            for j, ojtids in items:
                jtids = itids & ojtids
                if len(jtids) >= minsup:
                    suffix.append((j,jtids))

            dict_id += 1
            eclat(prefix+[i], sorted(suffix, key=lambda item: len(item[1]), reverse=True), dict_id)

def rules(FreqItems, confidence):
    Rules = []
    cnt = 0

    for items, support in FreqItems.items():
        if(len(items) > 1):
            lst = list(items)
            antecedent = lst[:len(lst) - 1]
            consequent = lst[-1:]
            
            conf = float(FreqItems[frozenset(items)]/FreqItems[frozenset(antecedent)])
            if (conf >= confidence):
                cnt += 1
                Rules.append((antecedent, consequent, support, conf))

    print('Found %d Rules ' % (cnt))
    return Rules

def print_Frequent_Itemsets(output_freqitems,FreqItems):
    file = open(output_freqitems, 'w+')
    for item, support in FreqItems.items():
        file.write(" {} : {} \n".format(list(item), round(support,4)))




def print_Rules(output_file,Rules):
    file = open(output_file, 'w+')
    for a, b,supp, conf in sorted(Rules):
        file.write("Rule: {} ==> {} : {} : {} \n".format((a), (b), round(supp, 4),round(conf, 4)))
    file.close()

def Read_Data(filename, delimiter=','):
    data = {}
    trans = 0
    f = open(filename, 'r')
    for row in f:
        trans += 1
        for item in row.split(delimiter):
            if item not in data:
                data[item] = set()
            data[item].add(trans)
    f.close()
    return data



if __name__ == "__main__":
    
    minsup   = int(argv[2])
    confidence = float(argv[3])
    output_FreqItems = argv[4]
    output_Rules = argv[5]
    dict_id = 0
    data = Read_Data(argv[1], ' ') 

    eclat([], sorted(data.items(), key=lambda item: len(item[1]), reverse=True), dict_id)
    Rules = rules(FreqItems, confidence)
    print('found %d Frequent items'%len(FreqItems))
    print('Writing Rules .....')
    print_Frequent_Itemsets(output_FreqItems, FreqItems)
    print_Rules(output_Rules, Rules)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-9117d2709e9d> in <module>()
#      66
#      67 if __name__ == "__main__":
# ---> 68     minsup   = int(argv[2])
#      69     confidence = float(argv[3])
#      70     output_FreqItems = argv[4]
#
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\MUKUNDHAN\\AppData\\Roaming\\jupyter\\runtime\\kernel-b422fcef-8a11-4272-a379-28de099bec0f.json'

# %%
from sys import argv
import sys
from itertools import chain, combinations

# %%
argv[1]=r''
data = Read_Data(argv[1], ' ')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-e426499f2fa4> in <module>()
#       1 argv[1]="‪H:\end sem\Eclat\Eclat\store_data.txt"
# ----> 2 data = Read_Data(argv[1], ' ')
#
# <ipython-input-2-9117d2709e9d> in Read_Data(filename, delimiter)
#      53     data = {}
#      54     trans = 0
# ---> 55     f = open(filename, 'r')
#      56     for row in f:
#      57         trans += 1
#
# OSError: [Errno 22] Invalid argument: '\u202aH:\\end sem\\Eclat\\Eclat\\store_data.txt'

# %%
kot = 0
FreqItems = dict()
support = dict()
def eclat(prefix, items, dict_id):
    while items:
        i,itids = items.pop()
        isupp = len(itids)
        if isupp >= minsup:

            FreqItems[frozenset(prefix + [i])] = isupp
            suffix = []
            for j, ojtids in items:
                jtids = itids & ojtids
                if len(jtids) >= minsup:
                    suffix.append((j,jtids))

            dict_id += 1
            eclat(prefix+[i], sorted(suffix, key=lambda item: len(item[1]), reverse=True), dict_id)

def rules(FreqItems, confidence):
    Rules = []
    cnt = 0

    for items, support in FreqItems.items():
        if(len(items) > 1):
            lst = list(items)
            antecedent = lst[:len(lst) - 1]
            consequent = lst[-1:]
            
            conf = float(FreqItems[frozenset(items)]/FreqItems[frozenset(antecedent)])
            if (conf >= confidence):
                cnt += 1
                Rules.append((antecedent, consequent, support, conf))

    print('Found %d Rules ' % (cnt))
    return Rules

def print_Frequent_Itemsets(FreqItems):
    for item, support in FreqItems.items():
        print(" {} : {} \n".format(list(item), round(support,4)))




def print_Rules(Rules):
    for a, b,supp, conf in sorted(Rules):
        print("Rule: {} ==> {} : {} : {} \n".format((a), (b), round(supp, 4),round(conf, 4)))


def Read_Data(filename, delimiter=','):
    data = {}
    trans = 0
    f = open(filename, 'r')
    for row in f:
        trans += 1
        for item in row.split(delimiter):
            if item not in data:
                data[item] = set()
            data[item].add(trans)
    f.close()
    return data



if __name__ == "__main__":
    minsup   = int(20)
    confidence = float(0.4)
    dict_id = 0
    data="H:\end sem\Eclat\Eclat\store_data.txt"
    data = Read_Data(data, ' ') 
    eclat([], sorted(data.items(), key=lambda item: len(item[1]), reverse=True), dict_id)
    Rules = rules(FreqItems, confidence)
    print('found %d Frequent items'%len(FreqItems))
    print('Frequent itemsets')
    print_Frequent_Itemsets(FreqItems)
    print('rules')
    print_Rules(Rules)
# Out:
# Found 53 Rules
# found 269 Frequent items
# Frequent itemsets
#  ['pasta,spaghetti,mineral'] : 20
#
#  ['pasta,spaghetti,mineral', 'wheat'] : 20
#
#  ['fries,champagne\n'] : 20
#
#  ['cream,cooking'] : 20
#
#  ['burgers\n'] : 20
#
#  ['cheese,spaghetti,mineral'] : 21
#
#  ['turkey,ground'] : 21
#
#  ['smoothie,hot'] : 21
#
#  ['cooking'] : 21
#
#  ['water,vegetables'] : 21
#
#  ['tuna,frozen'] : 21
#
#  ['oil,low'] : 21
#
#  ['fat', 'oil,low'] : 21
#
#  ['shrimp,ground'] : 22
#
#  ['fries,energy'] : 22
#
#  ['fries,energy', 'drink\n'] : 20
#
#  ['fries,yogurt'] : 22
#
#  ['fries,fresh'] : 22
#
#  ['cheese,green'] : 22
#
#  ['cheese,green', 'tea\n'] : 20
#
#  ['oil,energy'] : 22
#
#  ['turkey,grated'] : 23
#
#  ['smoothie,low'] : 23
#
#  ['smoothie,low', 'fat'] : 23
#
#  ['burgers,fresh'] : 23
#
#  ['tuna,mineral'] : 23
#
#  ['fresh', 'tuna,mineral'] : 20
#
#  ['oil,frozen'] : 24
#
#  ['sauce,mineral'] : 24
#
#  ['turkey,herb'] : 24
#
#  ['turkey,herb', '&'] : 24
#
#  ['chocolate,frozen'] : 24
#
#  ['mix\n'] : 25
#
#  ['wine,frozen'] : 25
#
#  ['tomatoes,ground'] : 25
#
#  ['vegetables,parmesan'] : 25
#
#  ['candy'] : 25
#
#  ['candy', 'bars\n'] : 23
#
#  ['vegetables\n'] : 26
#
#  ['burgers,grated'] : 26
#
#  ['cake,french'] : 27
#
#  ['cake,french', 'fries\n'] : 20
#
#  ['pasta,mineral'] : 27
#
#  ['pasta,mineral', 'wheat'] : 27
#
#  ['water,cooking'] : 27
#
#  ['juice,green'] : 27
#
#  ['juice,green', 'tea\n'] : 22
#
#  ['muffins\n'] : 27
#
#  ['wine,ground'] : 27
#
#  ['juice,low'] : 27
#
#  ['juice,low', 'fat'] : 27
#
#  ['dessert'] : 28
#
#  ['fries,cottage'] : 28
#
#  ['smoothie,cottage'] : 28
#
#  ['hot'] : 28
#
#  ['dogs\n', 'hot'] : 20
#
#  ['turkey,frozen'] : 28
#
#  ['water,eggs\n'] : 28
#
#  ['shrimp,mineral'] : 29
#
#  ['pepper\n'] : 29
#
#  ['herb', 'pepper\n'] : 21
#
#  ['herb', '&', 'pepper\n'] : 21
#
#  ['&', 'pepper\n'] : 24
#
#  ['cheese,whole'] : 29
#
#  ['cheese,whole', 'wheat'] : 29
#
#  ['fries,hot'] : 30
#
#  ['turkey,mineral'] : 31
#
#  ['yogurt'] : 31
#
#  ['yogurt', 'cake\n'] : 25
#
#  ['rice,cooking'] : 32
#
#  ['wheat', 'rice,cooking'] : 32
#
#  ['bread,low'] : 32
#
#  ['yogurt\n', 'bread,low'] : 28
#
#  ['yogurt\n', 'fat', 'bread,low'] : 28
#
#  ['fat', 'bread,low'] : 32
#
#  ['water,green'] : 32
#
#  ['water,green', 'tea\n'] : 20
#
#  ['beef\n'] : 32
#
#  ['ground', 'beef\n'] : 21
#
#  ['juice,fresh'] : 32
#
#  ['juice,fresh', 'bread\n'] : 21
#
#  ['fries,cookies\n'] : 33
#
#  ['burgers,ground'] : 33
#
#  ['bread,green'] : 33
#
#  ['bread,green', 'tea\n'] : 31
#
#  ['rice,french'] : 33
#
#  ['wheat', 'rice,french'] : 31
#
#  ['pepper,frozen'] : 33
#
#  ['pepper,frozen', '&'] : 31
#
#  ['fries,low'] : 33
#
#  ['fries,low', 'yogurt\n'] : 27
#
#  ['fries,low', 'yogurt\n', 'fat'] : 27
#
#  ['fries,low', 'fat'] : 33
#
#  ['water,energy'] : 33
#
#  ['vegetables,spaghetti,mineral'] : 33
#
#  ['tomatoes,mineral'] : 34
#
#  ['wine,mineral'] : 34
#
#  ['water,milk,olive'] : 34
#
#  ['pasta,ground'] : 34
#
#  ['pasta,ground', 'wheat'] : 34
#
#  ['burgers,frozen'] : 36
#
#  ['oil,green'] : 36
#
#  ['tomato'] : 36
#
#  ['fries,escalope\n'] : 37
#
#  ['beef,tomato'] : 37
#
#  ['vegetables,whole'] : 37
#
#  ['vegetables,whole', 'wheat'] : 37
#
#  ['food\n'] : 37
#
#  ['eggs,french'] : 38
#
#  ['fries\n', 'eggs,french'] : 21
#
#  ['yogurt,green'] : 38
#
#  ['yogurt,green', 'tea\n'] : 35
#
#  ['fat', 'yogurt,green', 'tea\n'] : 35
#
#  ['yogurt,green', 'fat'] : 38
#
#  ['vegetables'] : 39
#
#  ['pancakes\n'] : 39
#
#  ['milk\n'] : 40
#
#  ['water,whole'] : 42
#
#  ['water,whole', 'mineral'] : 21
#
#  ['water,whole', 'wheat', 'mineral'] : 21
#
#  ['water,whole', 'wheat'] : 42
#
#  ['burgers,mineral'] : 43
#
#  ['pepper,mineral'] : 44
#
#  ['pepper,mineral', '&'] : 30
#
#  ['champagne\n'] : 45
#
#  ['cheese,frozen'] : 46
#
#  ['grated', 'cheese,frozen'] : 29
#
#  ['water,french'] : 46
#
#  ['low'] : 46
#
#  ['yogurt\n', 'low'] : 45
#
#  ['yogurt\n', 'low', 'fat'] : 45
#
#  ['low', 'fat'] : 46
#
#  ['chocolate,french'] : 47
#
#  ['chocolate,french', 'fries\n'] : 22
#
#  ['cheese,herb'] : 49
#
#  ['cheese,herb', 'grated'] : 35
#
#  ['cheese,herb', '&', 'grated'] : 35
#
#  ['cheese,herb', '&'] : 49
#
#  ['fries,green'] : 51
#
#  ['fries,green', 'tea\n'] : 51
#
#  ['parmesan'] : 51
#
#  ['protein'] : 52
#
#  ['bar\n', 'protein'] : 25
#
#  ['free'] : 52
#
#  ['bar\n', 'free'] : 30
#
#  ['spaghetti\n'] : 52
#
#  ['cheese,mineral'] : 54
#
#  ['cheese,mineral', 'grated'] : 29
#
#  ['spray\n'] : 60
#
#  ['oil,french'] : 63
#
#  ['tea,french'] : 64
#
#  ['olive'] : 67
#
#  ['olive', 'oil\n'] : 24
#
#  ['cheese,ground'] : 67
#
#  ['grated', 'cheese,ground'] : 39
#
#  ['pepper,ground'] : 68
#
#  ['herb', 'pepper,ground'] : 44
#
#  ['&', 'herb', 'pepper,ground'] : 44
#
#  ['&', 'pepper,ground'] : 68
#
#  ['bars\n'] : 69
#
#  ['weat'] : 70
#
#  ['shrimp,frozen'] : 77
#
#  ['energy'] : 85
#
#  ['drink\n', 'energy'] : 20
#
#  ['bar\n', 'energy'] : 23
#
#  ['eggs\n'] : 90
#
#  ['dark'] : 90
#
#  ['dark', 'chocolate\n'] : 26
#
#  ['vegetables,ground'] : 91
#
#  ['vegetables,ground', 'beef,mineral'] : 28
#
#  ['frozen', 'vegetables,ground'] : 33
#
#  ['water,olive'] : 94
#
#  ['water,olive', 'mineral'] : 20
#
#  ['rice\n'] : 96
#
#  ['rice\n', 'wheat'] : 92
#
#  ['sauce\n'] : 97
#
#  ['cream', 'sauce\n'] : 77
#
#  ['chocolate\n'] : 99
#
#  ['spaghetti,mineral'] : 100
#
#  ['escalope\n'] : 101
#
#  ['fries,frozen'] : 103
#
#  ['smoothie\n', 'fries,frozen'] : 23
#
#  ['dogs\n'] : 103
#
#  ['vegetables,mineral'] : 106
#
#  ['vegetables,mineral', 'frozen'] : 57
#
#  ['beef,spaghetti,mineral'] : 109
#
#  ['beef,spaghetti,mineral', 'ground'] : 27
#
#  ['wine\n'] : 118
#
#  ['red'] : 123
#
#  ['cheese\n'] : 133
#
#  ['cheese\n', 'grated'] : 22
#
#  ['drink\n'] : 135
#
#  ['mayo\n'] : 135
#
#  ['juice\n'] : 140
#
#  ['cream'] : 143
#
#  ['fresh'] : 143
#
#  ['fresh', 'bread\n'] : 20
#
#  ['whole'] : 150
#
#  ['whole', 'tea\n'] : 20
#
#  ['whole', 'wheat', 'tea\n'] : 20
#
#  ['whole', 'wheat'] : 142
#
#  ['oil\n'] : 151
#
#  ['green'] : 154
#
#  ['green', 'tea\n'] : 89
#
#  ['cake\n'] : 156
#
#  ['beef,mineral'] : 156
#
#  ['wheat', 'beef,mineral'] : 22
#
#  ['&', 'beef,mineral'] : 25
#
#  ['ground', 'beef,mineral'] : 39
#
#  ['bar\n'] : 161
#
#  ['smoothie\n'] : 163
#
#  ['smoothie\n', 'frozen'] : 30
#
#  ['water\n'] : 183
#
#  ['water\n', 'mineral'] : 93
#
#  ['bread\n'] : 217
#
#  ['wheat', 'bread\n'] : 22
#
#  ['ground'] : 218
#
#  ['ground', 'tea\n'] : 31
#
#  ['cookies\n'] : 223
#
#  ['herb'] : 232
#
#  ['yogurt\n', 'herb'] : 21
#
#  ['yogurt\n', 'herb', 'fat'] : 21
#
#  ['yogurt\n', 'herb', '&', 'fat'] : 21
#
#  ['yogurt\n', 'herb', '&'] : 21
#
#  ['herb', 'fat'] : 25
#
#  ['herb', '&', 'fat'] : 25
#
#  ['herb', 'wheat'] : 26
#
#  ['herb', '&', 'wheat'] : 26
#
#  ['herb', '&'] : 232
#
#  ['french'] : 262
#
#  ['french', 'fries\n'] : 134
#
#  ['grated'] : 293
#
#  ['yogurt\n', 'grated'] : 26
#
#  ['yogurt\n', 'grated', 'fat'] : 26
#
#  ['grated', 'fat'] : 28
#
#  ['wheat', 'grated'] : 28
#
#  ['grated', 'tea\n'] : 32
#
#  ['&', 'grated'] : 35
#
#  ['&'] : 371
#
#  ['&', 'tea\n'] : 38
#
#  ['yogurt\n', '&'] : 39
#
#  ['yogurt\n', '&', 'fat'] : 39
#
#  ['&', 'fat'] : 44
#
#  ['wheat', '&'] : 48
#
#  ['frozen'] : 405
#
#  ['yogurt\n', 'frozen'] : 36
#
#  ['yogurt\n', 'frozen', 'fat'] : 36
#
#  ['frozen', 'tea\n'] : 40
#
#  ['frozen', 'fat'] : 41
#
#  ['frozen', 'wheat'] : 53
#
#  ['fries\n'] : 473
#
#  ['mineral', 'fries\n'] : 24
#
#  ['wheat', 'fries\n'] : 27
#
#  ['yogurt\n'] : 513
#
#  ['yogurt\n', 'wheat'] : 52
#
#  ['yogurt\n', 'wheat', 'fat'] : 52
#
#  ['yogurt\n', 'mineral'] : 58
#
#  ['yogurt\n', 'mineral', 'fat'] : 58
#
#  ['yogurt\n', 'fat'] : 513
#
#  ['fat'] : 574
#
#  ['tea\n', 'fat'] : 35
#
#  ['mineral', 'fat'] : 60
#
#  ['wheat', 'fat'] : 64
#
#  ['mineral'] : 577
#
#  ['wheat', 'mineral'] : 37
#
#  ['mineral', 'tea\n'] : 48
#
#  ['wheat'] : 645
#
#  ['wheat', 'tea\n'] : 88
#
#  ['tea\n'] : 803
#
# rules
# Rule: ['bread,green'] ==> ['tea\n'] : 31 : 0.9394
#
# Rule: ['cake,french'] ==> ['fries\n'] : 20 : 0.7407
#
# Rule: ['candy'] ==> ['bars\n'] : 23 : 0.92
#
# Rule: ['cheese,green'] ==> ['tea\n'] : 20 : 0.9091
#
# Rule: ['cheese,herb'] ==> ['&'] : 49 : 1.0
#
# Rule: ['cheese,herb'] ==> ['grated'] : 35 : 0.7143
#
# Rule: ['cheese,herb', '&'] ==> ['grated'] : 35 : 0.7143
#
# Rule: ['cheese,mineral'] ==> ['grated'] : 29 : 0.537
#
# Rule: ['cheese,whole'] ==> ['wheat'] : 29 : 1.0
#
# Rule: ['chocolate,french'] ==> ['fries\n'] : 22 : 0.4681
#
# Rule: ['cream'] ==> ['sauce\n'] : 77 : 0.5385
#
# Rule: ['fat', 'yogurt,green'] ==> ['tea\n'] : 35 : 0.9211
#
# Rule: ['french'] ==> ['fries\n'] : 134 : 0.5115
#
# Rule: ['fries,energy'] ==> ['drink\n'] : 20 : 0.9091
#
# Rule: ['fries,green'] ==> ['tea\n'] : 51 : 1.0
#
# Rule: ['fries,low'] ==> ['fat'] : 33 : 1.0
#
# Rule: ['fries,low'] ==> ['yogurt\n'] : 27 : 0.8182
#
# Rule: ['fries,low', 'yogurt\n'] ==> ['fat'] : 27 : 1.0
#
# Rule: ['green'] ==> ['tea\n'] : 89 : 0.5779
#
# Rule: ['herb'] ==> ['&'] : 232 : 1.0
#
# Rule: ['juice,fresh'] ==> ['bread\n'] : 21 : 0.6562
#
# Rule: ['juice,green'] ==> ['tea\n'] : 22 : 0.8148
#
# Rule: ['juice,low'] ==> ['fat'] : 27 : 1.0
#
# Rule: ['low'] ==> ['fat'] : 46 : 1.0
#
# Rule: ['pasta,ground'] ==> ['wheat'] : 34 : 1.0
#
# Rule: ['pasta,mineral'] ==> ['wheat'] : 27 : 1.0
#
# Rule: ['pasta,spaghetti,mineral'] ==> ['wheat'] : 20 : 1.0
#
# Rule: ['pepper,frozen'] ==> ['&'] : 31 : 0.9394
#
# Rule: ['pepper,mineral'] ==> ['&'] : 30 : 0.6818
#
# Rule: ['rice\n'] ==> ['wheat'] : 92 : 0.9583
#
# Rule: ['smoothie,low'] ==> ['fat'] : 23 : 1.0
#
# Rule: ['turkey,herb'] ==> ['&'] : 24 : 1.0
#
# Rule: ['vegetables,mineral'] ==> ['frozen'] : 57 : 0.5377
#
# Rule: ['vegetables,whole'] ==> ['wheat'] : 37 : 1.0
#
# Rule: ['water\n'] ==> ['mineral'] : 93 : 0.5082
#
# Rule: ['water,green'] ==> ['tea\n'] : 20 : 0.625
#
# Rule: ['water,whole'] ==> ['mineral'] : 21 : 0.5
#
# Rule: ['water,whole'] ==> ['wheat'] : 42 : 1.0
#
# Rule: ['water,whole', 'wheat'] ==> ['mineral'] : 21 : 0.5
#
# Rule: ['whole'] ==> ['wheat'] : 142 : 0.9467
#
# Rule: ['yogurt'] ==> ['cake\n'] : 25 : 0.8065
#
# Rule: ['yogurt\n'] ==> ['fat'] : 513 : 1.0
#
# Rule: ['yogurt\n', '&'] ==> ['fat'] : 39 : 1.0
#
# Rule: ['yogurt\n', 'frozen'] ==> ['fat'] : 36 : 1.0
#
# Rule: ['yogurt\n', 'grated'] ==> ['fat'] : 26 : 1.0
#
# Rule: ['yogurt\n', 'herb'] ==> ['&'] : 21 : 1.0
#
# Rule: ['yogurt\n', 'herb'] ==> ['fat'] : 21 : 1.0
#
# Rule: ['yogurt\n', 'herb', '&'] ==> ['fat'] : 21 : 1.0
#
# Rule: ['yogurt\n', 'low'] ==> ['fat'] : 45 : 1.0
#
# Rule: ['yogurt\n', 'mineral'] ==> ['fat'] : 58 : 1.0
#
# Rule: ['yogurt\n', 'wheat'] ==> ['fat'] : 52 : 1.0
#
# Rule: ['yogurt,green'] ==> ['fat'] : 38 : 1.0
#
# Rule: ['yogurt,green'] ==> ['tea\n'] : 35 : 0.9211
